# %%
#pip install --upgrade transformers

# %%
import torch
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.1663, 0.5202, 0.5164],
#         [0.9450, 0.3579, 0.1683],
#         [0.4645, 0.8751, 0.2942],
#         [0.9694, 0.4753, 0.2821],
#         [0.9369, 0.4169, 0.7351]])

# %%
from transformers import AutoTokenizer, T5ForConditionalGeneration

# %%
tokenizer = AutoTokenizer.from_pretrained("google-t5/t5-small")
# Out:
# config.json: 0.00B [00:00, ?B/s]
# C:\Users\APARNA KUMARI\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:138: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\APARNA KUMARI\.cache\huggingface\hub\models--google-t5--t5-small. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]

# %%
pip install torch torchvision torchaudio
# Out:
# Requirement already satisfied: torch in c:\users\aparna kumari\anaconda3\lib\site-packages (2.11.0)
# Requirement already satisfied: torchvision in c:\users\aparna kumari\anaconda3\lib\site-packages (0.26.0)
# Requirement already satisfied: torchaudio in c:\users\aparna kumari\anaconda3\lib\site-packages (2.11.0)
# Requirement already satisfied: filelock in c:\users\aparna kumari\anaconda3\lib\site-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\aparna kumari\appdata\roaming\python\python313\site-packages (from torch) (4.12.2)
# Requirement already satisfied: setuptools<82 in c:\users\aparna kumari\anaconda3\lib\site-packages (from torch) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\aparna kumari\anaconda3\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\aparna kumari\anaconda3\lib\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in c:\users\aparna kumari\appdata\roaming\python\python313\site-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\aparna kumari\anaconda3\lib\site-packages (from torch) (2025.10.0)
# Requirement already satisfied: numpy in c:\users\aparna kumari\appdata\roaming\python\python313\site-packages (from torchvision) (2.1.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\aparna kumari\appdata\roaming\python\python313\site-packages (from torchvision) (11.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\aparna kumari\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\aparna kumari\appdata\roaming\python\python313\site-packages (from jinja2->torch) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\aparna kumari\appdata\roaming\python\python313\site-packages (25.0)
# Collecting pip
#   Using cached pip-26.0.1-py3-none-any.whl.metadata (4.7 kB)
# Using cached pip-26.0.1-py3-none-any.whl (1.8 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 25.0
#     Uninstalling pip-25.0:
#       Successfully uninstalled pip-25.0
# Successfully installed pip-25.3
# Note: you may need to restart the kernel to use updated packages.
# WARNING: There was an error checking the latest version of pip.

# %%
model = T5ForConditionalGeneration.from_pretrained("google-t5/t5-small")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 model = T5ForConditionalGeneration.from_pretrained("google-t5/t5-small")
#
# File ~\anaconda3\Lib\site-packages\transformers\utils\import_utils.py:2035, in DummyObject.__getattribute__(cls, key)
#    2033 if (key.startswith("_") and key != "_from_config") or key == "is_dummy" or key == "mro" or key == "call":
#    2034     return super().__getattribute__(key)
# -> 2035 requires_backends(cls, cls._backends)
#
# File ~\anaconda3\Lib\site-packages\transformers\utils\import_utils.py:2021, in requires_backends(obj, backends)
#    2018         failed.append(msg.format(name))
#    2020 if failed:
# -> 2021     raise ImportError("".join(failed))
#
# ImportError:
# T5ForConditionalGeneration requires the PyTorch library but it was not found in your environment. Check out the instructions on the
# installation page: https://pytorch.org/get-started/locally/ and follow the ones that match your environment.
# Please note that you may need to restart your runtime after installation.

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\APARNA KUMARI\anaconda3\python.exe

# %%
# Out:
#   Cell In[1], line 1
#     git init
#         ^
# SyntaxError: invalid syntax
