# %%
# !pip install nltk
# Out:
# Unable to create process using 'C:\Users\APARNA KUMARI\anaconda3\python.exe "C:\Users\APARNA KUMARI\anaconda3\Scripts\pip-script.py" install nltk'

# %%
# !pip install pandas
# Out:
# Unable to create process using 'C:\Users\APARNA KUMARI\anaconda3\python.exe "C:\Users\APARNA KUMARI\anaconda3\Scripts\pip-script.py" install pandas'
